# %% [markdown]
# <a href="https://colab.research.google.com/github/mahesh45892/Tic-tac-toe-/blob/main/tic_tac_toe_micro_it_project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def print_board(board):
    for row in board:
        print(" | ".join(row))
        print("-" * 5)


def check_winner(board, player):
    # Check rows
    for row in board:
        if all(cell == player for cell in row):
            return True

    # Check columns
    for col in range(3):
        if all(board[row][col] == player for row in range(3)):
            return True

    # Check diagonals
    if all(board[i][i] == player for i in range(3)) or \
       all(board[i][2 - i] == player for i in range(3)):
        return True

    return False


def is_full(board):
    return all(cell != " " for row in board for cell in row)


def tic_tac_toe():
    board = [[" " for _ in range(3)] for _ in range(3)]
    current_player = "X"

    while True:
        print_board(board)
        print(f"Player {current_player}'s turn.")

        try:
            row = int(input("Enter row (0, 1, or 2): "))
            col = int(input("Enter column (0, 1, or 2): "))
        except ValueError:
            print("Please enter valid numbers.")
            continue

        if row not in range(3) or col not in range(3):
            print("Invalid input. Try again.")
            continue

        if board[row][col] != " ":
            print("Cell already taken. Try again.")
            continue

        board[row][col] = current_player

        if check_winner(board, current_player):
            print_board(board)
            print(f"Player {current_player} wins!")
            break

        if is_full(board):
            print_board(board)
            print("It's a tie!")
            break

        current_player = "O" if current_player == "X" else "X"


if __name__ == "__main__":
    tic_tac_toe()
# Out:
#   |   |
# -----
#   |   |
# -----
#   |   |
# -----
# Player X's turn.
# Enter row (0, 1, or 2): 1
# Enter column (0, 1, or 2): 2
#   |   |
# -----
#   |   | X
# -----
#   |   |
# -----
# Player O's turn.
# Enter row (0, 1, or 2): 1
# Enter column (0, 1, or 2): 1
#   |   |
# -----
#   | O | X
# -----
#   |   |
# -----
# Player X's turn.
# Enter row (0, 1, or 2): 0
# Enter column (0, 1, or 2): 2
#   |   | X
# -----
#   | O | X
# -----
#   |   |
# -----
# Player O's turn.
# Enter row (0, 1, or 2): 2
# Enter column (0, 1, or 2): 2
#   |   | X
# -----
#   | O | X
# -----
#   |   | O
# -----
# Player X's turn.
# Enter row (0, 1, or 2): 2
# Enter column (0, 1, or 2): 1
#   |   | X
# -----
#   | O | X
# -----
#   | X | O
# -----
# Player O's turn.
# Enter row (0, 1, or 2): 0
# Enter column (0, 1, or 2): 0
# O |   | X
# -----
#   | O | X
# -----
#   | X | O
# -----
# Player O wins!
